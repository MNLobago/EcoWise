# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
from fractions import Fraction
from model_scoring import ModelScorer

# %matplotlib inline

# %%
results_df = pd.read_csv("model_responses_with_time_tqdm3S.csv")

results_df.head()
# Out:
#                                             question  \
# 0  Which of the following foods takes the least e...
# 1  Which of the following are carbon sources? Sel...
# 2  Which of the following are carbon sinks? Selec...
# 3  Forests are carbon sinks because they remove c...
# 4  Human activities add greenhouse gases to the a...
#
#                                         model_answer  \
# 0  Question:\nWhich of the following foods takes ...
# 1  Question:\nWhich of the following are carbon s...
# 2  Question:\nWhich of the following are carbon s...
# 3  Question:\nForests are carbon sinks because th...
# 4  Question:\nHuman activities add greenhouse gas...
#
#                                     expected_answer                 category  \
# 0                              ['Fresh vegetables']  Food and Sustainability
# 1  ['Fossil fuel combustion', 'Volcanic eruptions']           Carbon Sources
# 2           ['Soil and rocks', 'Forests', 'Oceans']             Carbon Sinks
# 3                                    Photosynthesis             Carbon Cycle
# 4                                           Sources             Human Impact
#
#    response_time Human_EvaluatorScore  Max_Score
# 0      39.799639                    1          1
# 1      39.786446                    2          2
# 2      40.345988                    2          3
# 3      50.975232                    1          1
# 4      32.824526                    1          1

# %%
results_df['Human_EvaluatorScore'] = results_df['Human_EvaluatorScore'].apply(
    lambda x: float(Fraction(x)) if isinstance(x, str) and '/' in x else pd.to_numeric(x)
)
results_df['Max_Score'] = pd.to_numeric(results_df['Max_Score'])

# %%
results_df.Human_EvaluatorScore.unique()
# Out:
# array([1.  , 2.  , 0.  , 0.25, 4.  , 0.5 ])

# %%
results_df.Human_EvaluatorScore.value_counts()
# Out:
# Human_EvaluatorScore
# 1.00    44
# 0.00    20
# 2.00     4
# 0.25     1
# 4.00     1
# 0.50     1
# Name: count, dtype: int64

# %%
np.sum(results_df.Max_Score), np.sum(results_df.Human_EvaluatorScore)
# Out:
# (98, 56.75)

# %%
results_df['Max_Score'].value_counts()
# Out:
# Max_Score
# 1    56
# 2     8
# 4     5
# 3     2
# Name: count, dtype: int64

# %%
results_df.category.value_counts()
# Out:
# category
# Fossil Fuels                      5
# Greenhouse Gases                  4
# Carbon Cycle                      3
# Climate Change                    3
# Nonrenewable Resources            2
# Renewable Energy                  2
# Human Impact                      2
# Carbon Footprint                  2
# Carbon Footprint Reduction        2
# Carbon Sources                    2
# Climate Change Rate               1
# Historical CO2 Levels             1
# Natural Climate Change            1
# Food and Sustainability           1
# Global Temperature Change         1
# Carbon Dioxide Increase           1
# Paleoclimatology                  1
# Greenhouse Effect                 1
# Waste Management                  1
# Greenhouse Gas Sources            1
# Misconceptions                    1
# Scientific Consensus              1
# Carbon Management                 1
# Cumulative Emissions              1
# CO2 Lifetime                      1
# Future Climate Scenarios          1
# Ocean Acidification               1
# Coral Bleaching                   1
# Sea Level Rise                    1
# Emissions Reduction Strategies    1
# Fossil Fuel Consumption           1
# Environmental Marketing           1
# Ocean Health                      1
# Consequences of Climate Change    1
# Science Process                   1
# Carbon Sinks                      1
# Awareness                         1
# Climate Science                   1
# Waste and Sustainability          1
# Energy Efficiency                 1
# Water Conservation                1
# Sustainability                    1
# Environmental Impact              1
# Fossil Formation                  1
# Plastic Pollution                 1
# Renewable Energy Benefits         1
# Energy Conservation               1
# Nitrogen Cycle                    1
# Air Quality                       1
# Biodiversity                      1
# Sustainable Agriculture           1
# Deforestation                     1
# Energy Sources                    1
# Human Impact on Climate           1
# Name: count, dtype: int64

# %%
# Group by category and plot average score per category
category_performance = results_df.groupby('category')['Human_EvaluatorScore'].mean().sort_values()

plt.figure(figsize=(12, 8))
category_performance.plot(kind='barh', color='skyblue')
plt.title('Average Model Score by Category')
plt.xlabel('Average Score')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# Alright `Carbon sinks` has the largest score this isn't Iformative Enough since The differnt questions had differnt score based On:
# 1) Number of chooces that were correct
# 2) Was the answere clear Enough ?
# <p><b>Let's Drill Deeper</b></p>

# %% [markdown]
# **Some categories only had one Qustion relted to it let's put them off for a while**

# %%
# Filter categories with more than 1 question
min_samples = 2
category_performance = results_df.groupby('category').filter(lambda x: len(x) >= min_samples)

# Now, compute the average score per category
category_performance_avg = category_performance.groupby('category')['Human_EvaluatorScore'].mean().sort_values()

# Plot the average score per category for those with sufficient samples
plt.figure(figsize=(12, 8))
category_performance_avg.plot(kind='barh', color='skyblue')
plt.title('Average Model Score by Category (Only Categories with > 1 Sample)')
plt.xlabel('Average Score')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# Alright Seems like our model had a greater score for `Climate change`, followed by `Green House Gases` then a tie between `Non-Renewable Resources`, `Human Impact`, `Carbon sources`, `Carbon Footprint Reduction`, `Carbon Footprint` Intresting

# %%
# Filter categories with more than 1 question
min_samples = 2
category_performance = results_df.groupby('category').filter(lambda x: len(x) >= min_samples)

# Calculate the average score per category
category_performance_avg = category_performance.groupby('category')['Human_EvaluatorScore'].mean()

# Calculate the max score per category
category_max_score = category_performance.groupby('category')['Max_Score'].max()

# Combine the two into a DataFrame for comparison
category_comparison = pd.DataFrame({
    'Average Score': category_performance_avg,
    'Max Score': category_max_score
}).sort_values(by='Average Score', ascending=False)

# Plot the average and max scores for each category
plt.figure(figsize=(12, 8))
category_comparison.plot(kind='barh', color=['skyblue', 'lightcoral'])
plt.title('Average Model Score vs Max Score by Category')
plt.xlabel('Score')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# In comparison to Max possible score `Climate change` , `Greenhouse Gases` tend to be the leading but have quite a huge GAP with the Maximum posible score, `Caron FootPrin` has the maximum possible score and the largest margine between model score and MAX score is evident in `Carbon Footprint Reduction`
#
# <p>What Does this Mean we need to <b>Dive in deeper</b> to our results</p>

# %%
# Plot stacked bar of Average Score and Max Score for comparison
plt.figure(figsize=(12, 8))
category_comparison[['Average Score', 'Max Score']].plot(kind='barh', stacked=True, color=['skyblue', 'lightcoral'])
plt.title('Stacked Comparison of Average Score vs Max Score by Category')
plt.xlabel('Score')
plt.ylabel('Category')
plt.show()

# %%
# Calculate normalized performance (average score / max score)
category_comparison['Normalized Performance'] = category_comparison['Average Score'] / category_comparison['Max Score']

# Plot the normalized performance for each category
plt.figure(figsize=(12, 8))
category_comparison['Normalized Performance'].plot(kind='barh', color='seagreen')
plt.title('Normalized Model Performance by Category')
plt.xlabel('Normalized Performance (Avg Score / Max Score)')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(12, 8))
category_comparison['Normalized Performance'].sort_values().plot(kind='barh', color='lightgreen')
plt.title('Relative Model Performance (Avg Score / Max Score) by Category')
plt.xlabel('Normalized Performance')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# On the Normalized Point of view best Qusetions Categories that our model Did best are :
# 1) `Non-Renewable Rseources`
# 2) `Human Impact`
# 3) `Carbon Footprint`

# %%
# Normalize performance
category_comparison['Normalized Performance'] = category_comparison['Average Score'] / category_comparison['Max Score']

# Add the number of samples per category as a size indicator
category_comparison['Category Size'] = category_performance.groupby('category').size()

# Plot Normalized Performance with size/color based on Category Size
plt.figure(figsize=(12, 8))
sb.scatterplot(data=category_comparison, x='Normalized Performance', y=category_comparison.index, size='Category Size', hue='Category Size', palette='viridis', sizes=(50, 500), legend=None, alpha=0.7)
plt.title('Normalized Performance by Category (Size indicates # of Samples)')
plt.xlabel('Normalized Performance (Avg Score / Max Score)')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# On Avetrage the Diverse Questions categories Look to be doing quite well On this model <B>NICE!</B>
# <p>Evident by</p>
#
# 1) `Renewable Energy`
# 2) `Greenhouse Gases`
# 3) `Climate Change`

# %%
# Calculate the number of samples per category
category_counts = results_df['category'].value_counts()

# Plot Performance vs. Category Size
plt.figure(figsize=(10, 6))
sb.scatterplot(data=category_comparison, x='Category Size', y='Normalized Performance', hue='Category Size', palette='viridis', size='Category Size', sizes=(50, 500), alpha=0.7)
plt.title('Model Performance vs. Category Size (Number of Samples)')
plt.xlabel('Category Size (Number of Samples)')
plt.ylabel('Normalized Performance (Avg Score / Max Score)')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sb.violinplot(data=results_df[results_df['category'].isin(category_comparison.index)], x='category', y='Human_EvaluatorScore', palette='Set2', inner="stick")
plt.title('Distribution of Model Scores by Category')
plt.xlabel('Category')
plt.ylabel('Model Score')
plt.xticks(rotation=90, ha='right')
plt.show()
# Out:
# /tmp/ipykernel_341321/4136312586.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=results_df[results_df['category'].isin(category_comparison.index)], x='category', y='Human_EvaluatorScore', palette='Set2', inner="stick")

# %% [markdown]
# Alrigt We our Human Model Scores Distributions seems to be quite Intesting But as of now for a later topic
# <P>#<B>Did it MYSELF</B></P>

# %% [markdown]
# ## USING Script to gauge our models Performace

# %%
# Initialize the scorer with desired parameters
scorer = ModelScorer(alpha=0.5, W_accuracy=0.8, W_time=0.2)

# %%
# Compute the scores
results_df = scorer.compute_scores(results_df)

# Display the results
print(results_df[['category', 'Final_Score', 'Normalized_Final_Score']])
# Out:
#                           category  Final_Score  Normalized_Final_Score
# 0          Food and Sustainability     0.853928                0.986531
# 1                   Carbon Sources     0.853932                0.986537
# 2                     Carbon Sinks     0.587068                0.659642
# 3                     Carbon Cycle     0.850623                0.982483
# 4                     Human Impact     0.856799                0.990048
# ..                             ...          ...                     ...
# 66  Emissions Reduction Strategies     0.449310                0.490895
# 67         Fossil Fuel Consumption     0.856722                0.989954
# 68                Greenhouse Gases     0.592292                0.666040
# 69                    Carbon Cycle     0.864348                0.999295
# 70         Human Impact on Climate     0.454386                0.497112
#
# [71 rows x 3 columns]

# %%
# Grouping by category and calculating the average for each scoring metric
summary_df = results_df.groupby('category').agg({
    'Human_EvaluatorScore': 'mean',
    'Max_Score': 'mean',
    'Accuracy_Ratio': 'mean',
    'Time_Penalty': 'mean',
    'Final_Score': 'mean',
    'Normalized_Final_Score': 'mean'
}).reset_index()

# Display the summary
summary_df
# Out:
#                           category  Human_EvaluatorScore  Max_Score  \
# 0                      Air Quality              0.000000        1.0
# 1                        Awareness              0.000000        1.0
# 2                     Biodiversity              2.000000        2.0
# 3                     CO2 Lifetime              1.000000        1.0
# 4                     Carbon Cycle              0.666667        1.0
# 5          Carbon Dioxide Increase              1.000000        1.0
# 6                 Carbon Footprint              1.000000        1.0
# 7       Carbon Footprint Reduction              1.000000        2.5
# 8                Carbon Management              0.000000        1.0
# 9                     Carbon Sinks              2.000000        3.0
# 10                  Carbon Sources              1.000000        1.5
# 11                  Climate Change              1.666667        2.0
# 12             Climate Change Rate              1.000000        1.0
# 13                 Climate Science              0.000000        1.0
# 14  Consequences of Climate Change              0.250000        1.0
# 15                 Coral Bleaching              0.000000        1.0
# 16            Cumulative Emissions              1.000000        1.0
# 17                   Deforestation              1.000000        1.0
# 18  Emissions Reduction Strategies              1.000000        2.0
# 19             Energy Conservation              0.000000        2.0
# 20               Energy Efficiency              1.000000        1.0
# 21                  Energy Sources              1.000000        1.0
# 22            Environmental Impact              1.000000        4.0
# 23         Environmental Marketing              1.000000        1.0
# 24         Food and Sustainability              1.000000        1.0
# 25                Fossil Formation              1.000000        4.0
# 26         Fossil Fuel Consumption              1.000000        1.0
# 27                    Fossil Fuels              0.600000        1.0
# 28        Future Climate Scenarios              0.000000        1.0
# 29       Global Temperature Change              1.000000        1.0
# 30               Greenhouse Effect              1.000000        1.0
# 31          Greenhouse Gas Sources              1.000000        2.0
# 32                Greenhouse Gases              1.250000        1.5
# 33           Historical CO2 Levels              1.000000        1.0
# 34                    Human Impact              1.000000        1.0
# 35         Human Impact on Climate              1.000000        2.0
# 36                  Misconceptions              0.000000        2.0
# 37          Natural Climate Change              0.000000        1.0
# 38                  Nitrogen Cycle              1.000000        1.0
# 39          Nonrenewable Resources              1.000000        1.0
# 40             Ocean Acidification              1.000000        1.0
# 41                    Ocean Health              1.000000        1.0
# 42                Paleoclimatology              1.000000        4.0
# 43               Plastic Pollution              1.000000        1.0
# 44                Renewable Energy              0.500000        1.0
# 45       Renewable Energy Benefits              0.000000        1.0
# 46                 Science Process              0.000000        1.0
# 47            Scientific Consensus              0.500000        1.0
# 48                  Sea Level Rise              0.000000        2.0
# 49                  Sustainability              1.000000        1.0
# 50         Sustainable Agriculture              1.000000        1.0
# 51                Waste Management              0.000000        1.0
# 52        Waste and Sustainability              1.000000        1.0
# 53              Water Conservation              0.000000        1.0
#
#     Accuracy_Ratio  Time_Penalty  Final_Score  Normalized_Final_Score
# 0         0.000000      0.273449     0.054690                0.007504
# 1         0.000000      0.258546     0.051709                0.003854
# 2         1.000000      0.269381     0.853876                0.986468
# 3         1.000000      0.269709     0.853942                0.986549
# 4         0.666667      0.296623     0.592658                0.666489
# 5         1.000000      0.282367     0.856473                0.989650
# 6         1.000000      0.309251     0.861850                0.996236
# 7         0.625000      0.277478     0.555496                0.620967
# 8         0.000000      0.297850     0.059570                0.013482
# 9         0.666667      0.268675     0.587068                0.659642
# 10        0.500000      0.276127     0.455225                0.498141
# 11        0.666667      0.266428     0.586619                0.659091
# 12        1.000000      0.273710     0.854742                0.987529
# 13        0.000000      0.279256     0.055851                0.008927
# 14        0.250000      0.277388     0.255478                0.253459
# 15        0.000000      0.295057     0.059011                0.012798
# 16        1.000000      0.275393     0.855079                0.987941
# 17        1.000000      0.265296     0.853059                0.985467
# 18        0.500000      0.246552     0.449310                0.490895
# 19        0.000000      0.278270     0.055654                0.008686
# 20        1.000000      0.274932     0.854986                0.987828
# 21        1.000000      0.290511     0.858102                0.991645
# 22        0.250000      0.266598     0.253320                0.250816
# 23        1.000000      0.318897     0.863779                0.998599
# 24        1.000000      0.269638     0.853928                0.986531
# 25        0.250000      0.281403     0.256281                0.254443
# 26        1.000000      0.283611     0.856722                0.989954
# 27        0.600000      0.279367     0.535873                0.596931
# 28        0.000000      0.259977     0.051995                0.004204
# 29        1.000000      0.284382     0.856876                0.990143
# 30        1.000000      0.274369     0.854874                0.987690
# 31        0.500000      0.257936     0.451587                0.493684
# 32        0.916667      0.308727     0.795079                0.914444
# 33        1.000000      0.312372     0.862474                0.997001
# 34        1.000000      0.289236     0.857847                0.991332
# 35        0.500000      0.271928     0.454386                0.497112
# 36        0.000000      0.268776     0.053755                0.006360
# 37        0.000000      0.278971     0.055794                0.008857
# 38        1.000000      0.281484     0.856297                0.989433
# 39        1.000000      0.282036     0.856407                0.989569
# 40        1.000000      0.278736     0.855747                0.988760
# 41        1.000000      0.258644     0.851729                0.983838
# 42        0.250000      0.266699     0.253340                0.250841
# 43        1.000000      0.263484     0.852697                0.985023
# 44        0.500000      0.250976     0.450195                0.491979
# 45        0.000000      0.274994     0.054999                0.007883
# 46        0.000000      0.299660     0.059932                0.013926
# 47        0.500000      0.279937     0.455987                0.499074
# 48        0.000000      0.266225     0.053245                0.005735
# 49        1.000000      0.303114     0.860623                0.994732
# 50        1.000000      0.319502     0.863900                0.998747
# 51        0.000000      0.314466     0.062893                0.017553
# 52        1.000000      0.278278     0.855656                0.988648
# 53        0.000000      0.270510     0.054102                0.006784

# %%
# Melt the DataFrame to "long" format
melted_df = summary_df.melt(id_vars='category', 
                             value_vars=['Human_EvaluatorScore', 'Final_Score', 
                                         'Normalized_Final_Score', 'Accuracy_Ratio', 
                                         'Time_Penalty'],
                             var_name='Metric', value_name='Score')

# Create a facet grid
g = sb.FacetGrid(melted_df, col='Metric', col_wrap=3, sharey=False, height=4)

# Map barplot onto the grid
g.map(sb.barplot, 'category', 'Score', palette='viridis')

# Rotate x-labels for better readability
g.set_xticklabels(rotation=45)

# Set descriptive titles for the facets
g.set_titles(col_template="{col_name}: Scores by Category")

# Set axis labels
g.set_axis_labels("Category", "Score")

# Set overall title for the figure
plt.subplots_adjust(top=0.85)  # This ensures we have space for the title above the plots
g.fig.suptitle("Performance Metrics by Category Across Different Evaluations", fontsize=16)

# Add the additional title "Model 3 Three" in green
# Use text() to place title; y=0.95 is just below the top of the figure
plt.figtext(0.5, 0.94, "Model 3 Three", ha='center', va='center', fontsize=20, color='green')

# Show the plot with tight layout
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout fitting for overall title

# Save the plot to a file
plt.savefig("performance_metrics_by_category.png", bbox_inches='tight')
plt.show()
# Out:
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /home/morgan/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
np.mean(summary_df["Normalized_Final_Score"])
# Out:
# 0.5922939574012885
